# %%
# %load_ext sql
# %sql duckdb://
# Out:
# MissingPackageError: Can't load plugin: sqlalchemy.dialects:duckdb
#
# To fix it, run this in your notebook: %pip install duckdb-engine --quiet
#
# For more details, see: https://jupysql.ploomber.io/en/latest/howto/db-drivers.html#duckdb
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %pip install duckdb-engine --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# run this in your notebook
# %conda install psycopg2 -c conda-forge --yes --quiet
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - psycopg2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20220623.0      |       he4e09e4_6          16 KB  conda-forge
#     arrow-cpp-10.0.1           |   h7747421_4_cpu          29 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     aws-sdk-cpp-1.9.379        |       h0d16128_5         2.8 MB  conda-forge
#     base58-2.1.1               |     pyhd8ed1ab_0           9 KB  conda-forge
#     boost-cpp-1.73.0           |      h1a28f6b_12          17 KB
#     boto3-1.28.64              |     pyhd8ed1ab_0          77 KB  conda-forge
#     conda-23.9.0               |  py311h267d04e_2         1.2 MB  conda-forge
#     conda-libmamba-solver-23.7.0|     pyhd8ed1ab_0          41 KB  conda-forge
#     cryptography-41.0.3        |  py311h3c57c4d_0         1.3 MB
#     curl-8.1.1                 |       h80987f9_0          85 KB
#     cyrus-sasl-2.1.27          |       h7c04901_5         230 KB  conda-forge
#     glog-0.6.0                 |       h6da1cb0_0          95 KB  conda-forge
#     grpc-cpp-1.51.1            |       h7747421_0          20 KB  conda-forge
#     gst-plugins-base-1.18.5    |       h5bf8608_3         2.0 MB  conda-forge
#     gstreamer-1.18.5           |       ha076c35_3         1.4 MB  conda-forge
#     hdf5-1.12.1                |nompi_hf9525e8_104         3.2 MB  conda-forge
#     icu-68.2                   |       hbdafb3b_0        13.0 MB  conda-forge
#     krb5-1.19.4                |       h8380606_0         1.2 MB
#     libabseil-20220623.0       | cxx17_h28b99d4_6         950 KB  conda-forge
#     libarchive-3.6.2           |       h0a93236_0         732 KB  conda-forge
#     libarrow-10.0.1            |   h8ce3b88_4_cpu        16.1 MB  conda-forge
#     libboost-1.73.0            |      h49e8a49_12        12.6 MB
#     libclang-13.0.1            |default_h0b16b43_6         5.9 MB  conda-forge
#     libcrc32c-1.1.2            |       hbdafb3b_0          18 KB  conda-forge
#     libcurl-8.1.1              |       h0f1d93c_0         343 KB
#     libevent-2.1.10            |       hbae9a57_4         1.2 MB  conda-forge
#     libgoogle-cloud-2.5.0      |       h7c6a1a0_1         5.2 MB  conda-forge
#     libgrpc-1.51.1             |       h503f348_0         3.0 MB  conda-forge
#     libllvm13-13.0.1           |       hfd59cb2_2        23.2 MB  conda-forge
#     libmamba-1.4.1             |       h48ca7d4_0         1.2 MB
#     libmambapy-1.4.1           |  py311h48ca7d4_0         249 KB
#     libnghttp2-1.51.0          |       hd184df1_0         548 KB  conda-forge
#     libntlm-1.4                |    h3422bc3_1002          31 KB  conda-forge
#     libogg-1.3.4               |       h27ca646_1         203 KB  conda-forge
#     libopus-1.3.1              |       h27ca646_1         247 KB  conda-forge
#     libpq-14.5                 |       hb650857_3         2.1 MB  conda-forge
#     libprotobuf-3.21.12        |       hb5ab8b9_0         1.7 MB  conda-forge
#     libssh2-1.10.0             |       hb80f160_3         218 KB  conda-forge
#     libthrift-0.16.0           |       h1a74c4f_2         334 KB  conda-forge
#     libutf8proc-2.8.0          |       h1a8c8d9_0         101 KB  conda-forge
#     libvorbis-1.3.7            |       h9f76cd9_0         249 KB  conda-forge
#     libxml2-2.10.4             |       h372ba2a_0         638 KB
#     libxslt-1.1.37             |       h1bd8bc4_0         231 KB  conda-forge
#     mysql-5.7.24               |       h2ed7f7c_0        28.0 MB
#     mysql-common-8.0.32        |       hab468bb_0         732 KB  conda-forge
#     mysql-libs-8.0.32          |       hea58576_0         1.5 MB  conda-forge
#     nspr-4.35                  |       hb7217d7_0         216 KB  conda-forge
#     nss-3.89                   |       h789eff7_0         1.7 MB  conda-forge
#     openssl-1.1.1w             |       h53f4e23_0         1.6 MB  conda-forge
#     orc-1.8.2                  |       hef0d403_2         352 KB  conda-forge
#     parquet-cpp-1.5.1          |                2           3 KB  conda-forge
#     protobuf-4.21.12           |  py311ha397e9f_0         342 KB  conda-forge
#     psycopg2-2.9.3             |  py311h4be0703_1         173 KB  conda-forge
#     pyarrow-10.0.1             |py311h0ec44e3_4_cpu         2.8 MB  conda-forge
#     pycurl-7.45.1              |  py311h3bda321_3          72 KB  conda-forge
#     pyopenssl-23.2.0           |     pyhd8ed1ab_1         126 KB  conda-forge
#     python-3.11.0              |hf452327_1_cpython        13.8 MB  conda-forge
#     qt-main-5.15.2             |       hfc65906_0        59.2 MB  conda-forge
#     re2-2022.06.01             |       h9a09cb3_1         162 KB  conda-forge
#     s3transfer-0.7.0           |     pyhd8ed1ab_1          60 KB  conda-forge
#     streamlit-1.8.0            |     pyhd8ed1ab_0         8.1 MB  conda-forge
#     yaml-cpp-0.7.0             |       hb7217d7_2         133 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       222.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   base58             conda-forge/noarch::base58-2.1.1-pyhd8ed1ab_0
#   boto3              conda-forge/noarch::boto3-1.28.64-pyhd8ed1ab_0
#   libabseil          conda-forge/osx-arm64::libabseil-20220623.0-cxx17_h28b99d4_6
#   libarrow           conda-forge/osx-arm64::libarrow-10.0.1-h8ce3b88_4_cpu
#   libcrc32c          conda-forge/osx-arm64::libcrc32c-1.1.2-hbdafb3b_0
#   libgoogle-cloud    conda-forge/osx-arm64::libgoogle-cloud-2.5.0-h7c6a1a0_1
#   libgrpc            conda-forge/osx-arm64::libgrpc-1.51.1-h503f348_0
#   libllvm13          conda-forge/osx-arm64::libllvm13-13.0.1-hfd59cb2_2
#   libntlm            conda-forge/osx-arm64::libntlm-1.4-h3422bc3_1002
#   libogg             conda-forge/osx-arm64::libogg-1.3.4-h27ca646_1
#   libopus            conda-forge/osx-arm64::libopus-1.3.1-h27ca646_1
#   libutf8proc        conda-forge/osx-arm64::libutf8proc-2.8.0-h1a8c8d9_0
#   libvorbis          conda-forge/osx-arm64::libvorbis-1.3.7-h9f76cd9_0
#   mysql-common       conda-forge/osx-arm64::mysql-common-8.0.32-hab468bb_0
#   mysql-libs         conda-forge/osx-arm64::mysql-libs-8.0.32-hea58576_0
#   nspr               conda-forge/osx-arm64::nspr-4.35-hb7217d7_0
#   nss                conda-forge/osx-arm64::nss-3.89-h789eff7_0
#   parquet-cpp        conda-forge/noarch::parquet-cpp-1.5.1-2
#   psycopg2           conda-forge/osx-arm64::psycopg2-2.9.3-py311h4be0703_1
#   s3transfer         conda-forge/noarch::s3transfer-0.7.0-pyhd8ed1ab_1
#
# The following packages will be UPDATED:
#
#   glog                     pkgs/main::glog-0.5.0-h313beb8_1 --> conda-forge::glog-0.6.0-h6da1cb0_0
#   grpc-cpp            pkgs/main::grpc-cpp-1.48.2-hc60591f_4 --> conda-forge::grpc-cpp-1.51.1-h7747421_0
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.1-h3~ --> conda-forge::gst-plugins-base-1.18.5-h5bf8608_3
#   gstreamer          pkgs/main::gstreamer-1.14.1-h80987f9_1 --> conda-forge::gstreamer-1.18.5-ha076c35_3
#   hdf5                    pkgs/main::hdf5-1.12.1-h05c076b_3 --> conda-forge::hdf5-1.12.1-nompi_hf9525e8_104
#   libiconv              pkgs/main::libiconv-1.16-h1a28f6b_2 --> conda-forge::libiconv-1.17-h0d3ecfb_2
#   libpq                   pkgs/main::libpq-12.17-h02f6b3c_0 --> conda-forge::libpq-14.5-hb650857_3
#   libprotobuf        pkgs/main::libprotobuf-3.20.3-h514c7b~ --> conda-forge::libprotobuf-3.21.12-hb5ab8b9_0
#   libssh2              pkgs/main::libssh2-1.10.0-h02f6b3c_2 --> conda-forge::libssh2-1.10.0-hb80f160_3
#   libthrift          pkgs/main::libthrift-0.15.0-h73c2103_2 --> conda-forge::libthrift-0.16.0-h1a74c4f_2
#   orc                       pkgs/main::orc-1.7.4-hdca1487_1 --> conda-forge::orc-1.8.2-hef0d403_2
#   protobuf           pkgs/main::protobuf-3.20.3-py311h313b~ --> conda-forge::protobuf-4.21.12-py311ha397e9f_0
#   re2                  pkgs/main::re2-2022.04.01-hc377ac9_0 --> conda-forge::re2-2022.06.01-h9a09cb3_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   abseil-cpp         pkgs/main::abseil-cpp-20230802.0-h313~ --> conda-forge::abseil-cpp-20220623.0-he4e09e4_6
#   arrow-cpp          pkgs/main::arrow-cpp-14.0.2-hc7aafb3_1 --> conda-forge::arrow-cpp-10.0.1-h7747421_4_cpu
#   aws-sdk-cpp        pkgs/main::aws-sdk-cpp-1.10.55-h313be~ --> conda-forge::aws-sdk-cpp-1.9.379-h0d16128_5
#   conda-libmamba-so~ pkgs/main::conda-libmamba-solver-24.1~ --> conda-forge::conda-libmamba-solver-23.7.0-pyhd8ed1ab_0
#   cyrus-sasl         pkgs/main::cyrus-sasl-2.1.28-h9131b1a~ --> conda-forge::cyrus-sasl-2.1.27-h7c04901_5
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-68.2-hbdafb3b_0
#   libarchive         pkgs/main::libarchive-3.6.2-h62fee54_2 --> conda-forge::libarchive-3.6.2-h0a93236_0
#   libclang           pkgs/main::libclang-14.0.6-default_h1~ --> conda-forge::libclang-13.0.1-default_h0b16b43_6
#   libevent            pkgs/main::libevent-2.1.12-h02f6b3c_1 --> conda-forge::libevent-2.1.10-hbae9a57_4
#   libnghttp2         pkgs/main::libnghttp2-1.57.0-h62f6fdd~ --> conda-forge::libnghttp2-1.51.0-hd184df1_0
#   libxslt              pkgs/main::libxslt-1.1.37-h80987f9_1 --> conda-forge::libxslt-1.1.37-h1bd8bc4_0
#   pyarrow            pkgs/main::pyarrow-14.0.2-py311ha07b5~ --> conda-forge::pyarrow-10.0.1-py311h0ec44e3_4_cpu
#   pycurl             pkgs/main::pycurl-7.45.2-py311h02f6b3~ --> conda-forge::pycurl-7.45.1-py311h3bda321_3
#   pyopenssl          pkgs/main/osx-arm64::pyopenssl-24.0.0~ --> conda-forge/noarch::pyopenssl-23.2.0-pyhd8ed1ab_1
#   qt-main             pkgs/main::qt-main-5.15.2-h0917680_10 --> conda-forge::qt-main-5.15.2-hfc65906_0
#   streamlit          pkgs/main/osx-arm64::streamlit-1.16.0~ --> conda-forge/noarch::streamlit-1.8.0-pyhd8ed1ab_0
#   yaml-cpp             pkgs/main::yaml-cpp-0.8.0-h313beb8_0 --> conda-forge::yaml-cpp-0.7.0-hb7217d7_2
#
# The following packages will be DOWNGRADED:
#
#   boost-cpp                               1.82.0-h48ca7d4_2 --> 1.73.0-h1a28f6b_12
#   conda                              24.5.0-py311h267d04e_0 --> 23.9.0-py311h267d04e_2
#   cryptography                       42.0.5-py311hd4332d6_0 --> 41.0.3-py311h3c57c4d_0
#   curl                                     8.5.0-h02f6b3c_0 --> 8.1.1-h80987f9_0
#   krb5                                    1.20.1-hf3e1bf2_1 --> 1.19.4-h8380606_0
#   libboost                                1.82.0-h0bc93f9_2 --> 1.73.0-h49e8a49_12
#   libcurl                                  8.5.0-h3e2b118_0 --> 8.1.1-h0f1d93c_0
#   libmamba                                 1.5.6-h15e39b3_0 --> 1.4.1-h48ca7d4_0
#   libmambapy                          1.5.6-py311h1c5506f_0 --> 1.4.1-py311h48ca7d4_0
#   libxml2                                 2.10.4-h0dcf63f_1 --> 2.10.4-h372ba2a_0
#   mysql                                   5.7.24-ha71a6ea_2 --> 5.7.24-h2ed7f7c_0
#   openssl                                  3.3.0-hfb2fe0b_3 --> 1.1.1w-h53f4e23_0
#   python                          3.11.8-hdf0ec26_0_cpython --> 3.11.0-hf452327_1_cpython
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
CREATE TABLE sales (
    sale_id SERIAL PRIMARY KEY,
    product_id INT,
    employee_id INT,
    quantity INT,
    price DECIMAL,
    sale_date DATE
);
CREATE TABLE products (
    product_id SERIAL PRIMARY KEY,
    product_name VARCHAR(255),
    category VARCHAR(255),
    price DECIMAL
);
CREATE TABLE employees (
    employee_id SERIAL PRIMARY KEY,
    name VARCHAR(255),
    department_id INT,
    salary DECIMAL
);
CREATE TABLE departments (
    department_id SERIAL PRIMARY KEY,
    department_name VARCHAR(255)
);
INSERT INTO departments (department_name)
VALUES
('Sales'),
('Marketing'),
('IT'),
('HR'),
('Finance');
INSERT INTO employees (name, department_id, salary)
VALUES
('John Doe', 1, 50000),
('Jane Smith', 2, 55000),
('Alice Johnson', 3, 60000),
('Robert Brown', 4, 45000),
('Emily Davis', 5, 70000);
INSERT INTO products (product_name, category, price)
VALUES
('Laptop', 'Electronics', 1000),
('Smartphone', 'Electronics', 800),
('Tablet', 'Electronics', 500),
('Headphones', 'Accessories', 100),
('Charger', 'Accessories', 20);
INSERT INTO sales (product_id, employee_id, quantity, price, sale_date)
VALUES
(1, 1, 5, 1000, '2024-05-01'),
(2, 2, 10, 800, '2024-05-02'),
(3, 3, 7, 500, '2024-05-03'),
(4, 4, 15, 100, '2024-05-04'),
(5, 5, 20, 20, '2024-05-05');
# Out:
#   Cell In[1], line 2
#     CREATE TABLE sales (
#            ^
# SyntaxError: invalid syntax
